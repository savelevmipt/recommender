# %%
import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import svds

# %%
users = pd.read_csv("KION_DATASET/data_original/users.csv")

# %%
users
# Out:
#         user_id         age        income  sex  kids_flg
# 0        973171   age_25_34  income_60_90    М         1
# 1        962099   age_18_24  income_20_40    М         0
# 2       1047345   age_45_54  income_40_60    Ж         0
# 3        721985   age_45_54  income_20_40    Ж         0
# 4        704055   age_35_44  income_60_90    Ж         0
# ...         ...         ...           ...  ...       ...
# 840192   339025  age_65_inf   income_0_20    Ж         0
# 840193   983617   age_18_24  income_20_40    Ж         1
# 840194   251008         NaN           NaN  NaN         0
# 840195   590706         NaN           NaN    Ж         0
# 840196   166555  age_65_inf  income_20_40    Ж         0
#
# [840197 rows x 5 columns]

# %%
df = items = pd.read_csv("KION_DATASET/data_original/items.csv").set_index('item_id')

# %%
items[items['countries'] == "Россия"].sort_values('release_year').head(4)
# Out:
#         content_type                     title                title_orig
# item_id
# 6464            film    Проект инженера Прайта  Engineer Prite's Project  \
# 14452           film  Да Здравствует, Мексика!         ¡Que viva Mexico!
# 5258            film              Во имя жизни                       NaN
# 8018            film            Голубая стрела                       NaN
#
#          release_year                            genres countries  for_kids
# item_id
# 6464           1918.0  драмы, русские, короткометражные    Россия       NaN  \
# 14452          1931.0                    документальное    Россия       NaN
# 5258           1946.0                  драмы, советские    Россия       NaN
# 8018           1959.0                боевики, советские    Россия       NaN
#
#          age_rating studios                                directors
# item_id
# 6464           12.0     NaN                                      NaN  \
# ...

# %%
interactions = pd.read_csv('KION_DATASET/interactions.csv')

# %%
interactions[interactions["user_id"] == 391423].head(30)
# Out:
#         user_id  item_id last_watch_dt  total_dur  watched_pct
# 2114     391423     9265    2021-06-06     9618.0        100.0
# 203036   391423     3182    2021-04-24     5230.0         80.0
# 437416   391423     4436    2021-08-21     7588.0         86.0
# 451549   391423     7829    2021-08-14      252.0          4.0
# 657247   391423     1337    2021-08-09     2064.0         33.0
# 816455   391423     8741    2021-05-02        1.0          0.0

# %%
len(interactions)
# Out:
# 1594787

# %%
items[items['title'] == 'Раскол']
# Out:
#         content_type   title title_orig  release_year
# item_id
# 8406          series  Раскол        NaN        2011.0  \
#
#                                genres countries  for_kids  age_rating studios
# item_id
# 8406     драмы, исторические, русские    Россия       NaN        16.0     NaN  \
#
#                directors                                             actors
# item_id
# 8406     Николай Досталь  Александр Баширов, Александр Коротков, Алексан...  \
#
#                                                description
# item_id
# 8406     Один из самых дорогих исторических проектов на...  \
#
#                                                   keywords
# item_id
# 8406     Раскол, 2011, Россия, преодоление, трудностей,...

# %%
items[(items['genres'].str.contains("документальное")) & (items['countries'] == 'Россия')].head(2)
# Out:
#         content_type                                      title title_orig
# item_id
# 15702           film  Лев Яшин – Эдуард Стрельцов. Перекрестки…        NaN  \
# 11015           film             Не укради. Возвращение святыни        NaN
#
#          release_year                                 genres countries
# item_id
# 15702          2013.0                  спорт, документальное    Россия  \
# 11015          2018.0  исторические, русские, документальное    Россия
#
#          for_kids  age_rating studios      directors actors
# item_id
# 15702         NaN        12.0     NaN            NaN    NaN  \
# 11015         NaN        12.0     NaN  Николай Ахаян    NaN
#
#                                                description
# item_id
# 15702    Этот фильм проводит параллели судеб двух знаме...  \
# 11015    Документальный фильм о преступлении, произошед...
#
#                                                   keywords
# item_id
# ...

# %%
items[items['title'] == 'Великая война']
# Out:
#         content_type          title title_orig  release_year
# item_id
# 6249          series  Великая война        NaN        2010.0  \
#
#                                         genres countries  for_kids
# item_id
# 6249     исторические, военные, документальное    Россия       0.0  \
#
#          age_rating studios                    directors
# item_id
# 6249           12.0     NaN  Анна Граждан, Валерий Бабич  \
#
#                                    actors
# item_id
# 6249     Евгений Синчуков, Анатолий Богуш  \
#
#                                                description
# item_id
# 6249     Серия документальных картин, рассказывающих о ...  \
#
#                              keywords
# item_id
# 6249     Великая, война, 2010, Россия

# %%
items[items['title'].str.contains('Ералаш')].head(1)
# Out:
#         content_type              title title_orig  release_year    genres
# item_id
# 11783           film  Ералаш выпуск №18        NaN        1978.0  семейное  \
#
#         countries  for_kids  age_rating studios
# item_id
# 11783      Россия       NaN         6.0     NaN  \
#
#                                     directors actors
# item_id
# 11783    М. Давыдов, В. Горлов, И. Киасашвили    NaN  \
#
#                                                description
# item_id
# 11783    1. Урок геометрии. Ребята на последнее парте р...  \
#
#                                  keywords
# item_id
# 11783    1978, россия, ералаш, выпуск, 18

# %%
good_interactions = interactions[interactions['watched_pct'].notna()]
data_matrix = csr_matrix(
    (good_interactions.watched_pct.values,
    (good_interactions.user_id.values, good_interactions.item_id.values))
)

# %%
_, S, Vt = svds(data_matrix, k = 700, return_singular_vectors='vh')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 _, S, Vt = svds(data_matrix, k = 700, return_singular_vectors='vh')
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/sparse/linalg/_eigen/_svds.py:532, in svds(A, k, ncv, tol, which, v0, maxiter, return_singular_vectors, solver, random_state, options)
#     530 if v0 is None:
#     531     v0 = random_state.standard_normal(size=(min(A.shape),))
# --> 532 _, eigvec = eigsh(XH_X, k=k, tol=tol ** 2, maxiter=maxiter,
#     533                   ncv=ncv, which=which, v0=v0)
#     534 # arpack do not guarantee exactly orthonormal eigenvectors
#     535 # for clustered eigenvalues, especially in complex arithmetic
#     536 eigvec, _ = np.linalg.qr(eigvec)
#
# ...

# %%
favourite_movies_ids = [6336, 12725, 9265, 2221, 6249]
favourite_movies_ids = [11783, 6842]
favourite_movies_ids = [14089]
favourite_movies_ids = [15428]
favourite_movies_ids = [6249, 9214, 9817, 6945]
favourite_movies_ids = [6249]
favourite_movies_ids = [16429]

favourite_movies_ids = [10994]
favourite_movies_ids = [14089]
favourite_movies_ids = [15915]



items.loc[favourite_movies_ids]
# Out:
#         content_type             title         title_orig  release_year
# item_id
# 15915           film  Балканский рубеж  Balkanskiy rubezh        2019.0  \
#
#                           genres       countries  for_kids  age_rating
# item_id
# 15915    боевики, драмы, военные  Россия, Сербия       NaN        16.0  \
#
#         studios      directors
# item_id
# 15915       NaN  Андрей Волгин  \
#
#                                                     actors
# item_id
# 15915    Антон Пампушный, Гоша Куценко, Милош Бикович, ...  \
#
#                                                description
# item_id
# 15915    Югославия. 1999 год. Российская спецгруппа пол...  \
#
#                                         keywords
# item_id
# 15915    2019, россия, serbia, балканский, рубеж

# %%
items.loc[np.argsort(-Vt.T @ Vt[:, favourite_movies_ids].sum(axis = 1))[:15]]
# Out:
#         content_type                     title             title_orig
# item_id
# 15915           film          Балканский рубеж      Balkanskiy rubezh  \
# 298             film                     Война                  Voyna
# 881             film                 5-я волна           The 5th Wave
# 14141           film                Зубная фея            Tooth Fairy
# 8489            film                     Шакал             The Jackal
# 12232           film         Зачетный препод 3        Fack ju Göhte 3
# 3345            film                   Рэмбо 4                  Rambo
# 8730            film          Лучшие из лучших       Best of the Best
# 5005            film     Любовь не по сценарию                Rewrite
# 11469           film                   Инферно                Inferno
# 9774            film                   Кукушка               Kukushka
# 2296            film   Операция «Мёртвый снег»                Død snø
# ...

# %%
items
# Out:
#         content_type                 title      title_orig  release_year
# item_id
# 10711           film        Поговори с ней  Hable con ella        2002.0  \
# 2508            film           Голые перцы    Search Party        2014.0
# 10716           film      Тактическая сила  Tactical Force        2011.0
# 7868            film                45 лет        45 Years        2015.0
# 16268           film  Все решает мгновение             NaN        1978.0
# ...              ...                   ...             ...           ...
# 6443          series         Полярный круг   Arctic Circle        2018.0
# 2367          series               Надежда             NaN        2020.0
# 10632         series                Сговор          Hassel        2017.0
# 4538          series          Среди камней      Darklands         2019.0
# 3206          series                  Гоша             NaN        2019.0
#
#                                                    genres
# item_id
# ...
